# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler , LabelEncoder                                                                           
from sklearn.cluster import KMeans , DBSCAN
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/CC GENERAL.csv")
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data["MINIMUM_PAYMENTS"]= data["MINIMUM_PAYMENTS"].fillna(data["MINIMUM_PAYMENTS"].mean(), inplace=False)

# %%
data["CREDIT_LIMIT"] = data["CREDIT_LIMIT"].fillna(data["CREDIT_LIMIT"].mean(), inplace=False)

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
normalisationColumns = ['BALANCE','CASH_ADVANCE_TRX','PURCHASES_TRX','PURCHASES','ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES','CASH_ADVANCE','CREDIT_LIMIT','PAYMENTS','MINIMUM_PAYMENTS']

# %%
data[normalisationColumns] =StandardScaler().fit_transform(data[normalisationColumns])
data.head()
# Out:
#   CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001 -0.731989           0.818182  -0.424900         -0.356934
# 1  C10002  0.786961           0.909091  -0.469552         -0.356934
# 2  C10003  0.447135           1.000000  -0.107668          0.108889
# 3  C10004  0.049099           0.636364   0.232058          0.546189
# 4  C10005 -0.358775           1.000000  -0.462063         -0.347294
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.349079     -0.466786             0.166667
# 1               -0.454576      2.605605             0.000000
# 2               -0.454576     -0.466786             1.000000
# 3               -0.454576     -0.368653             0.083333
# 4               -0.454576     -0.466786             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000         -0.476070      -0.511333     -0.960433
# 1                0.250000          0.110074      -0.591796      0.688639
# 2                0.000000         -0.476070      -0.109020      0.826062
# 3                0.083333         -0.329534      -0.551565      0.826062
# 4                0.000000         -0.476070      -0.551565     -0.905464
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0 -0.528979         -0.310968          0.000000      12
# 1  0.818642          0.089310          0.222222      12
# 2 -0.383805         -0.101663          0.000000      12
# 3 -0.598688          0.000000          0.000000      12
# 4 -0.364368         -0.265791          0.000000      12

# %%
# data["TENURE"] = MinMaxScaler().fit_transform(data["TENURE"])   

x = data["TENURE"].to_frame()
data["TENURE"] = MinMaxScaler().fit_transform(x)

# %%
data.drop(columns=["CUST_ID"], inplace=True )

# %%
inerta= []  
for i in range (1,10) :
  k_means = KMeans(n_clusters=i)
  k_means.fit_transform(data)
  distance = k_means.inertia_
  inerta.append(distance) 

inerta
# Out:
# [95223.3246163906,
#  76917.03000845581,
#  64210.48783346951,
#  56864.17536385112,
#  52450.698572398134,
#  48759.90591488278,
#  44207.46174941477,
#  41935.98564248997,
#  39793.69109462108]

# %%
plt.plot(inerta, marker='o', markerfacecolor='yellow')

# %%
k_means = KMeans(n_clusters=4)
k_means.fit_transform(data)
# Out:
# array([[ 1.10553925,  4.98342672,  4.58745433, 21.14205888],
#        [ 3.52794979,  5.24476875,  2.05819589, 20.39165159],
#        [ 1.83147052,  3.80617521,  3.71123721, 20.16676803],
#        ...,
#        [ 1.44261552,  4.89670673,  4.74513157, 21.09254992],
#        [ 1.58239445,  5.27749131,  4.65287307, 21.29944791],
#        [ 1.62367539,  4.27988881,  4.53702904, 20.3501527 ]],
#       shape=(8950, 4))

# %%
labels = k_means.labels_
labels
# Out:
# array([0, 2, 0, ..., 0, 0, 0], shape=(8950,), dtype=int32)
